# %%
# !pip install langchain -i https://pypi.mirrors.ustc.edu.cn/simple
# !pip install langchain_community -i https://pypi.mirrors.ustc.edu.cn/simple
# Out:
# Looking in indexes: https://pypi.mirrors.ustc.edu.cn/simple
# Requirement already satisfied: langchain in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (0.2.15)
# Requirement already satisfied: PyYAML>=5.3 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain) (3.10.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.35 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain) (0.2.35)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain) (0.1.106)
# Requirement already satisfied: numpy<2,>=1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests<3,>=2->langchain) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: anyio in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.5)
# Requirement already satisfied: sniffio in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.35->langchain) (3.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.0)
# Looking in indexes: https://pypi.mirrors.ustc.edu.cn/simple
# Collecting langchain_community
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/d6/56/5070c4461bdd848b9c6dcd52a2b65074bf9d9aa8ac01c5fdb0df4d9aa470/langchain_community-0.2.13-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 62.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain_community) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain_community) (3.10.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/c3/be/d0d44e092656fe7a06b55e6103cbce807cdbdee17884a5367c68c9860853/dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Requirement already satisfied: langchain<0.3.0,>=0.2.15 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain_community) (0.2.15)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.35 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain_community) (0.2.35)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain_community) (0.1.106)
# Requirement already satisfied: numpy<2,>=1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/3c/78/c1de55eb3311f2c200a8b91724414b8d6f5ae78891c15d9d936ea43c3dba/marshmallow-3.22.0-py3-none-any.whl (49 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading https://mirrors.ustc.edu.cn/pypi/packages/65/f3/107a22063bf27bdccf2024833d3445f4eea42b2e598abfbd46f6a63b6cb0/typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain<0.3.0,>=0.2.15->langchain_community) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain<0.3.0,>=0.2.15->langchain_community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain_community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langchain-core<0.3.0,>=0.2.35->langchain_community) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from langsmith<0.2.0,>=0.1.0->langchain_community) (3.10.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests<3,>=2->langchain_community) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Requirement already satisfied: anyio in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community) (4.4.0)
# Requirement already satisfied: httpcore==1.* in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community) (1.0.5)
# Requirement already satisfied: sniffio in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.35->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.15->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.15->langchain_community) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain_community) (1.2.0)
# Installing collected packages: typing-inspect, marshmallow, dataclasses-json, langchain_community
# Successfully installed dataclasses-json-0.6.7 langchain_community-0.2.13 marshmallow-3.22.0 typing-inspect-0.9.0

# %%
# !pip install git+https://gitee.com/mindspore-lab/mindnlp
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting git+https://gitee.com/mindspore-lab/mindnlp
#   Cloning https://gitee.com/mindspore-lab/mindnlp to /tmp/pip-req-build-9odz47g1
#   Running command git clone --filter=blob:none --quiet https://gitee.com/mindspore-lab/mindnlp /tmp/pip-req-build-9odz47g1
#   Resolved https://gitee.com/mindspore-lab/mindnlp to commit ea6bc0e3990b7c30c9c2a4af0a8e4b4fa8dd62cc
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: mindspore>=2.2.14 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (2.3.0)
# Requirement already satisfied: tqdm in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (4.66.5)
# Requirement already satisfied: requests in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (2.32.3)
# Requirement already satisfied: datasets in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (2.21.0)
# Requirement already satisfied: evaluate in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (0.4.2)
# Requirement already satisfied: tokenizers==0.19.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (0.19.1)
# Requirement already satisfied: safetensors in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (0.4.4)
# Requirement already satisfied: sentencepiece in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (0.2.0)
# Requirement already satisfied: regex in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (2024.7.24)
# Requirement already satisfied: addict in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (2.4.0)
# Requirement already satisfied: ml_dtypes in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (0.4.0)
# Requirement already satisfied: pyctcdecode in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (0.5.0)
# Requirement already satisfied: jieba in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (0.42.1)
# Requirement already satisfied: pytest==7.2.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindnlp==0.4.0) (7.2.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pytest==7.2.0->mindnlp==0.4.0) (24.2.0)
# Requirement already satisfied: iniconfig in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pytest==7.2.0->mindnlp==0.4.0) (2.0.0)
# Requirement already satisfied: packaging in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pytest==7.2.0->mindnlp==0.4.0) (24.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pytest==7.2.0->mindnlp==0.4.0) (1.5.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pytest==7.2.0->mindnlp==0.4.0) (1.2.0)
# Requirement already satisfied: tomli>=1.0.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pytest==7.2.0->mindnlp==0.4.0) (2.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from tokenizers==0.19.1->mindnlp==0.4.0) (0.24.6)
# Requirement already satisfied: numpy<2.0.0,>=1.20.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindspore>=2.2.14->mindnlp==0.4.0) (1.26.4)
# Requirement already satisfied: protobuf>=3.13.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindspore>=2.2.14->mindnlp==0.4.0) (5.27.3)
# Requirement already satisfied: asttokens>=2.0.4 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindspore>=2.2.14->mindnlp==0.4.0) (2.0.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindspore>=2.2.14->mindnlp==0.4.0) (10.4.0)
# Requirement already satisfied: scipy>=1.5.4 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindspore>=2.2.14->mindnlp==0.4.0) (1.13.1)
# Requirement already satisfied: psutil>=5.6.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindspore>=2.2.14->mindnlp==0.4.0) (5.9.0)
# Requirement already satisfied: astunparse>=1.6.3 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from mindspore>=2.2.14->mindnlp==0.4.0) (1.6.3)
# Requirement already satisfied: filelock in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from datasets->mindnlp==0.4.0) (3.15.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from datasets->mindnlp==0.4.0) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from datasets->mindnlp==0.4.0) (0.3.8)
# Requirement already satisfied: pandas in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from datasets->mindnlp==0.4.0) (2.2.2)
# Requirement already satisfied: xxhash in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from datasets->mindnlp==0.4.0) (3.5.0)
# Requirement already satisfied: multiprocess in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from datasets->mindnlp==0.4.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets->mindnlp==0.4.0) (2024.6.1)
# Requirement already satisfied: aiohttp in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from datasets->mindnlp==0.4.0) (3.10.5)
# Requirement already satisfied: pyyaml>=5.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from datasets->mindnlp==0.4.0) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests->mindnlp==0.4.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests->mindnlp==0.4.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests->mindnlp==0.4.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests->mindnlp==0.4.0) (2024.7.4)
# Requirement already satisfied: pygtrie<3.0,>=2.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pyctcdecode->mindnlp==0.4.0) (2.5.0)
# Requirement already satisfied: hypothesis<7,>=6.14 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pyctcdecode->mindnlp==0.4.0) (6.111.2)
# Requirement already satisfied: six in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from asttokens>=2.0.4->mindspore>=2.2.14->mindnlp==0.4.0) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from astunparse>=1.6.3->mindspore>=2.2.14->mindnlp==0.4.0) (0.43.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp->datasets->mindnlp==0.4.0) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp->datasets->mindnlp==0.4.0) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp->datasets->mindnlp==0.4.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp->datasets->mindnlp==0.4.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp->datasets->mindnlp==0.4.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from aiohttp->datasets->mindnlp==0.4.0) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers==0.19.1->mindnlp==0.4.0) (4.11.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from hypothesis<7,>=6.14->pyctcdecode->mindnlp==0.4.0) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pandas->datasets->mindnlp==0.4.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pandas->datasets->mindnlp==0.4.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pandas->datasets->mindnlp==0.4.0) (2024.1)
# Building wheels for collected packages: mindnlp
#   Building wheel for mindnlp (setup.py) ... done
#   Created wheel for mindnlp: filename=mindnlp-0.4.0-py3-none-any.whl size=8293511 sha256=9775620c819815d995b275f8cd15578604e0bab99f9cd83ebf8a2430d03a9771
#   Stored in directory: /tmp/pip-ephem-wheel-cache-v_ebvow0/wheels/7c/fd/78/fee6d065e54e239d0fa743942f3b0b9caf73f63bf76d7b50ee
# Successfully built mindnlp
# Installing collected packages: mindnlp
# Successfully installed mindnlp-0.4.0

# %%
# !pip install faiss-cpu
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting faiss-cpu
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/f9/71/5e22c2a2e3e3edb8902c41f9d307fc989c738f45bfa120a3b92d1c71d6af/faiss_cpu-1.8.0.post1-cp39-cp39-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 109.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.0,>=1.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from faiss-cpu) (24.1)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.8.0.post1

# %%
from typing import List

from langchain.embeddings.base import Embeddings

from mindnlp.sentence import SentenceTransformer


class EmbeddingsFunAdapter(Embeddings):
    def __init__(self, embed_model, mirror='huggingface'):
        self.embed_model = embed_model
        self.embedding_model = SentenceTransformer(model_name_or_path=self.embed_model, mirror=mirror)

    def embed_documents(self, texts: List[str]) -> List[List[float]]:
        embeddings = self.embedding_model.encode_texts(texts)
        return embeddings

    def embed_query(self, text: str) -> List[float]:
        embeddings = self.embedding_model.encode_texts([text])
        return embeddings[0]
# Out:
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:549: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 1.087 seconds.
# Prefix dict has been built successfully.

# %%
# !pip install streamlit
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting streamlit
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/7c/2e/60e624bbe16f4baa45cb6e48a1ee05edd48a0a14cceec4d7eec9258755ac/streamlit-1.38.0-py2.py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 133.2 MB/s eta 0:00:00
# Requirement already satisfied: altair<6,>=4.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (5.4.0)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/bb/2a/10164ed1f31196a2f7f3799368a821765c62851ead0e630ab52b8e14b4d0/blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Collecting cachetools<6,>=4.0 (from streamlit)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/a4/07/14f8ad37f2d12a5ce41206c21820d8cb6561b728e51fad4530dff0552a67/cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: click<9,>=7.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (5.27.3)
# Requirement already satisfied: pyarrow>=7.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (4.11.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (3.1.43)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ab/4c/b888e6cf58bd9db9c93f40d1c6be8283ff49d88919231afe93a6bcf61626/pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 145.0 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from streamlit) (6.4.1)
# Collecting watchdog<5,>=2.1.5 (from streamlit)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/8a/b1/25acf6767af6f7e44e0086309825bd8c098e301eed5868dc5350642124b9/watchdog-4.0.2-py3-none-manylinux2014_aarch64.whl (82 kB)
# Requirement already satisfied: jinja2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.1.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (1.5.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (2024.7.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /home/mindspore/miniconda/envs/jupyter/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Installing collected packages: watchdog, cachetools, blinker, pydeck, streamlit
# Successfully installed blinker-1.8.2 cachetools-5.5.0 pydeck-0.9.1 streamlit-1.38.0 watchdog-4.0.2

# %%
import json
from langchain.document_loaders.base import BaseLoader
from langchain.schema import Document
from langchain.indexes import VectorstoreIndexCreator
from langchain.text_splitter import CharacterTextSplitter

class LineByLineJSONLoader(BaseLoader):
    def __init__(self, file_path):
        self.file_path = file_path

    def load(self):
        documents = []
        with open(self.file_path, 'r', encoding='utf-8') as file:
            for line in file:
                json_obj = json.loads(line)
                # 提取并格式化 JSON 数据
                content = (
                    f"Name: {json_obj.get('name', '')}\n"
                    f"Description: {json_obj.get('desc', '')}\n"
                    f"Category: {', '.join(json_obj.get('category', []))}\n"
                    f"Prevent: {json_obj.get('prevent', '')}\n"
                    f"Cause: {json_obj.get('cause', '')}\n"
                    f"Symptom: {', '.join(json_obj.get('symptom', []))}\n"
                    f"Get Probability: {json_obj.get('get_prob', '')}\n"
                    f"Get Way: {json_obj.get('get_way', '')}\n"
                    f"Accompany: {', '.join(json_obj.get('acompany', []))}\n"
                    f"Cure Department: {', '.join(json_obj.get('cure_department', []))}\n"
                    f"Common Drug: {', '.join(json_obj.get('common_drug', []))}\n"
                    f"Recommend Drug: {', '.join(json_obj.get('recommand_drug', []))}\n"
                    f"Easy Get: {', '.join(json_obj.get('easy_get', []))}\n"
                    f"Medical Insurance status: {json_obj.get('yibao_status', '')}\n"
                    f"Cure Way: {', '.join(json_obj.get('cure_way', []))}\n"
                    f"Cure Last Time: {json_obj.get('cure_lasttime', '')}\n"
                    f"Cured Probability: {json_obj.get('cured_prob', '')}\n"
                    f"Cost Money: {json_obj.get('cost_money', '')}\n"
                    f"Check: {', '.join(json_obj.get('check', []))}\n"
                    f"Recommend Drug: {', '.join(json_obj.get('recommand_drug', []))}\n"
                    f"Drug Detail: {', '.join(json_obj.get('drug_detail', []))}\n"
                    f"Do Eat: {', '.join(json_obj.get('do_eat', []))}\n"
                    f"Don't eat: {', '.join(json_obj.get('not_eat', []))}\n"
                    f"Recommend Eat: {', '.join(json_obj.get('recommand_eat', []))}\n"
                )
                
                # 创建文档对象
                documents.append(Document(page_content=content, metadata={'id': json_obj.get('_id', '')}))
        return documents

# 使用自定义加载器
loader = LineByLineJSONLoader('dataset/medical.json')
documents = loader.load()

# 文本切分
splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
split_documents = []
for doc in documents:
    split_docs = splitter.split_text(doc.page_content)
    for split_doc in split_docs:
        split_documents.append(Document(page_content=split_doc, metadata=doc.metadata))

# %%
import argparse
from langchain_community.vectorstores import FAISS
from langchain.text_splitter import CharacterTextSplitter
import streamlit as st

import mindspore
from mindnlp.transformers import AutoTokenizer, AutoModelForCausalLM

def load_knowledge_base(split_documents):
    texts = [doc.page_content for doc in documents]
    embeddings = EmbeddingsFunAdapter("AI-ModelScope/m3e-base", mirror='modelscope')
    faiss = FAISS.from_texts(texts, embeddings)
    return faiss


def load_model_and_tokenizer(model_path):
    model = AutoModelForCausalLM.from_pretrained(model_path, ms_dtype=mindspore.float16)
    model.set_train(False)
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    return tokenizer, model

# 返回对应的knowledge
def retrieve_knowledge(faiss, query):
    docs = faiss.similarity_search(query)
    return docs[0].page_content

# 将knowlege和query叠加生成input，调用模型chat返回response
def generate_answer(tokenizer, model, query, knowledge):
    input_text = knowledge + query
    #这一步要再formulate下加个prompt
    response = model.chat(tokenizer, input_text, temperature=0.001)
    answer = response[0]
    return answer


def rag_pipeline(faiss, tokenizer, model, query, use_rag):
    if use_rag:
        knowledge = retrieve_knowledge(faiss, query)
        answer = generate_answer(tokenizer, model, query, knowledge)
        return answer, knowledge
    else:
        answer = generate_answer(tokenizer, model, query, "")
        return answer, ""

# %%
model_path = "./.mindnlp/model/ZhipuAI/glm-4-9b-chat"
st.title("RAG Demo")
faiss = load_knowledge_base(split_documents)
tokenizer, model = load_model_and_tokenizer(model_path)

if 'answer' not in st.session_state:
    st.session_state['answer'] = ""

if 'knowledge' not in st.session_state:
    st.session_state['knowledge'] = ""

with st.form(key='chat_form', clear_on_submit=True):
    query = st.text_input("输入您的问题：", "")
    use_rag = st.checkbox("启用检索增强生成 (RAG)", value=True)
    submitted = st.form_submit_button("发送")

if submitted and query:
    answer, knowledge = rag_pipeline(faiss, tokenizer, model, query, use_rag)
    st.session_state['answer'] = answer
    st.session_state['knowledge'] = knowledge

elif submitted:
    st.warning("请输入一个问题。")

with st.subheader("用户输入"):
    st.text_area("User Query", query, height=50)

    # 左右布局
left_column, right_column = st.columns(2)

with left_column:
    st.subheader("回答")
    st.text_area("Assistant Answer", st.session_state['answer'], height=300)

with right_column:
    st.subheader("知识检索")
    st.text_area("Knowledge", st.session_state['knowledge'], height=300)

    # 重新运行以刷新对话历史
if submitted:
    st.rerun()
# Out:
# 2024-08-28 15:27:17.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-08-28 15:27:17.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# No sentence-transformers model found with name AI-ModelScope/m3e-base. Creating a new one with MEAN pooling.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 4
#       2 st.title("RAG Demo")
#       3 faiss = load_knowledge_base(split_documents)
# ----> 4 tokenizer, model = load_model_and_tokenizer(model_path)
#       6 if 'answer' not in st.session_state:
#       7     st.session_state['answer'] = ""
#
# Cell In[22], line 17, in load_model_and_tokenizer(model_path)
#      16 def load_model_and_tokenizer(model_path):
# ---> 17     model = AutoModelForSeq2SeqLM.from_pretrained(model_path, ms_dtype=mindspore.float16)
#      18     model.set_train(False)
#      19     tokenizer = AutoTokenizer.from_pretrained(model_path)
#
# File ~/miniconda/envs/jupyter/lib/python3.9/site-packages/mindnlp/transformers/models/auto/auto_factory.py:513, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     509     model_class = _get_model_class(config, cls._model_mapping)
#     510     return model_class.from_pretrained(
#     511         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     512     )
# --> 513 raise ValueError(
#     514     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     515     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     516 )
#
# ValueError: Unrecognized configuration class <class 'mindnlp.transformers.models.chatglm4.configuration_chatglm4.ChatGLM4Config'> for this kind of AutoModel: AutoModelForSeq2SeqLM.
# Model type should be one of BartConfig, BigBirdPegasusConfig, BlenderbotConfig, BlenderbotSmallConfig, ChatGLMConfig, FSMTConfig, LEDConfig, M2M100Config, MarianConfig, MBartConfig, MT5Config, MvpConfig, PegasusConfig, PegasusXConfig, PLBartConfig, ProphetNetConfig, SwitchTransformersConfig, T5Config, UMT5Config, XLMProphetNetConfig.
